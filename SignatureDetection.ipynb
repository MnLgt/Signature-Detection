# %%
# import warnings
# warnings.simplefilter("ignore", category=UserWarning)

# %%
import os
from scripts.execution_status import execution_status
from PIL import ImageOps, Image
from diffusers.utils import load_image
from pathlib import Path
import random

# %%
image_dir = Path('assets')
# list any images with jpg or png format
images = [str(image) for image in image_dir.iterdir() if image.suffix in ['.jpg', '.png']]
image_path = random.choice(images)
image_name = os.path.basename(image_path)
print(image_name)

image = load_image(image_path).convert("RGB")
image.resize((100, 100))
# Out:
# signed_agreement_3.jpg
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
num_sig_pages, status, boxes, crops = execution_status([image], show=True)
# Out:
# Status: SIGNED_BLOCK
# Score: 0.9970794916152954
# Status: SIGNED_BLOCK
# Score: 0.9968022108078003
# Status: SIGNED_BLOCK
# Score: 0.9935937523841858
# Status: SIGNED_BLOCK
# Score: 0.9926725029945374
# Status: SIGNED_BLOCK
# Score: 0.9738981127738953
